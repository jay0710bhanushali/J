# %%
import numpy as np
class myFuzzySet:
  def __init__(self, a, b, c):
    self.Left = a
    self.Center = b
    self.Right = c

  def membership(self, x):
    if x <= self.Center:
      return (x - self.Left) / (self.Center - self.Left)
    elif x <= self.Right:
      return (self.Right - x) / (self.Right - self.Center)
    else:
      return 0

  def area(self):
    return(self.Right - self.Center)

temperature_below_average = myFuzzySet(15, 30, 45)

temperature_low = myFuzzySet(-5, 10, 25)

pressure_below_average = myFuzzySet(1.25, 2, 2.75)

pressure_low = myFuzzySet(0.25, 1, 1.75)

heating_power_medium_high = myFuzzySet(3.25, 4, 4.75)

heating_power_high = myFuzzySet(4.25, 5, 5.75)

valve_opening_medium_low = myFuzzySet(1.25, 2, 2.75)

valve_opening_small = myFuzzySet(0.25, 1, 1.75)

temperature_input = 17.5
pressure_input = 1.3

z1 = min(temperature_below_average.membership(temperature_input), pressure_below_average.membership(pressure_input))
z2 = min(temperature_low.membership(temperature_input), pressure_low.membership(pressure_input))

print("z1 = ", z1)
print("z2 = ", z2)
# Out:
# z1 =  0.06666666666666672
# z2 =  0.5

# %%
c1num = (z1 * heating_power_medium_high.area() * heating_power_medium_high.Center) + (z2 * heating_power_high.area() * heating_power_high.Center)
c2num = (z1 * valve_opening_medium_low.area() * valve_opening_medium_low.Center) + (z2 * valve_opening_small.area() * valve_opening_small.Center)
c1den = (z1 * heating_power_medium_high.area() + z2 * heating_power_high.area())
c2den = (z1 * valve_opening_medium_low.area() + z2 * valve_opening_small.area())

c1 = c1num/c1den
c2 = c2num/c2den

print("C1 = ", c1,)
print("C2 = ", c2)
# Out:
# C1 =  4.88235294117647
# C2 =  1.1176470588235294
